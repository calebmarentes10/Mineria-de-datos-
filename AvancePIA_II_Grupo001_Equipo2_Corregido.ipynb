# %% [markdown]
# <a href="https://colab.research.google.com/github/calebmarentes10/Mineria-de-datos-/blob/main/AvancePIA_II_Grupo001_Equipo2_Corregido.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Equipo 2**
# Grupo: 001 Lunes de 7:00 – 10:00
#
# **Integrantes:**
# * 1851976 Marentes Camarillo Caleb
# - 1851600 Garnica Cardenas Maria Fernanda
# - 1941526 Morales Garcia Ismael
# - 1797297 Garcia Partida Yael Alejandro
# - 1726507 Vidal Barriga Dayanne Alejandra

# %% [markdown]
# ###**TOP 50 BESTSELLERS BOOKS 2009-2019**
# ![libros.jpeg](data:image/jpeg;base64,...)
# ***Url de la pagina:***  https://www.kaggle.com/sootersaalu/amazon-top-50-bestselling-books-2009-2019

# %% [markdown]
# ***Introducción general:***
#
# Top 50 bestselling books 2009-2019 es una base de datos que consta de 50 libros más vendidos en un rango de 10 años donde podremos encontrar nombre del libro, su autor, reseñas, precios, género, entre otras.
#
# Con estos datos pretendemos alentar al público a darle la oportunidad a alguna historia y salir de su zona de confort, por lo que será de gran ayuda tener reseñas de personas que hayan leído aquellas historias y dado su testimonio.
#
# Así mismo, consideramos que estos datos son útiles para el tema de creación de películas, ¿a quien no le gustaría ver en la pantalla grande su libro preferido? Por lo que con los datos recopilados podremos ver hacia qué género o autor se inclina más la gente así como saber cual es el promedio, máximo y mínimo de calificaciones, de la misma manera, podremos saber cuál es el más y menos comprado dentro de esta lista

# %% [markdown]
# **Descripción de los datos:**
#
# Los datos provienen de las plataformas de Amazon donde se han acomodado en 7 columnas de la siguiente manera:
#
# Nombre:En esta columna podremos apreciar el título del libro
#
# Autor: Nos indica quién escribió el libro
#
# Calificacion del Usuario: En esa seccion se hizo un promedio de todas las calificaciones que recibió el libro por lo que encontraremos calificaciones desde 3.3 hasta 4.9 siendo la máxima
#
# Reseñas: En esta columna podremos observar el número de personas que hicieron un comentario acerca del libro, no viene detallada en sí el comentario era bueno o malo pero eso lo deducimos en base a la calificación.
#
# Precio: Precio promedio en el que se vendió
#
# Año: Año de publicación
#
# Género: Nos indica si es de ciencia ficción o no, en esta columna no detalla mas generos pero si tenemos conocimiento de los autores nos damos una idea de que tipo de lectura es

# %% [markdown]
# **Justificación del uso de datos:**
#
# Decidimos ocupar esta base de datos por dos razones la primera fue que nos gustaría saber cuales son las características de los libros más vendidos y la segunda sería para poder hacer una recomendación a la comunidad de algún libro fácil de leer y con esto empezar el hábito de la lectura.
#
# Algunos de los beneficios para trabajar con esta base de datos es que fácilmente podemos indagar en que es lo que caracteriza a un best-seller, desde autor hasta precio

# %% [markdown]
# **Objetivo final:**
#
# Nuestro objetivo final es hacer un análisis completo de toda la base y con esto saber cuales son las principales características para convertirse en un best-seller.

# %% [markdown]
# **Preguntas de interés:**
#
# ¿Cuál es el precio promedio de un best seller?
#
# ¿Cual es el numero promedio de reviews?
#
# **Limpieza de datos**
#
# Comenzamos importando librerias y bases de datos

# %%
import pandas as pd
import numpy as np
import json

bdsellers = pd.read_csv("bestsellers.csv",encoding='utf8')

# %% [markdown]
# Visualizacion de datos

# %%
bdsellers
# Out:
#                                                   Name  ...        Genre
# 0                        10-Day Green Smoothie Cleanse  ...  Non Fiction
# 1                                    11/22/63: A Novel  ...      Fiction
# 2              12 Rules for Life: An Antidote to Chaos  ...  Non Fiction
# 3                               1984 (Signet Classics)  ...      Fiction
# 4    5,000 Awesome Facts (About Everything!) (Natio...  ...  Non Fiction
# ..                                                 ...  ...          ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  ...      Fiction
# 546  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 547  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 548  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 549  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
#
# [550 rows x 7 columns]

# %% [markdown]
# Continuaremos con revisar la cantidad de filas y columnas de la base

# %%
bdsellers.shape
# Out:
# (550, 7)

# %% [markdown]
# Aqui lo que hicimos con la funcion .head es ver los primeros 10 elementos de cada columna

# %%
bdsellers.head(10)
# Out:
#                                                 Name  ...        Genre
# 0                      10-Day Green Smoothie Cleanse  ...  Non Fiction
# 1                                  11/22/63: A Novel  ...      Fiction
# 2            12 Rules for Life: An Antidote to Chaos  ...  Non Fiction
# 3                             1984 (Signet Classics)  ...      Fiction
# 4  5,000 Awesome Facts (About Everything!) (Natio...  ...  Non Fiction
# 5      A Dance with Dragons (A Song of Ice and Fire)  ...      Fiction
# 6  A Game of Thrones / A Clash of Kings / A Storm...  ...      Fiction
# 7                     A Gentleman in Moscow: A Novel  ...      Fiction
# 8      A Higher Loyalty: Truth, Lies, and Leadership  ...  Non Fiction
# 9                          A Man Called Ove: A Novel  ...      Fiction
#
# [10 rows x 7 columns]

# %% [markdown]
# Aqui lo que hicimos con la funcion .tail es ver los ultimos 10 elementos de cada columna

# %%
bdsellers.tail(10)
# Out:
#                                                   Name  ...        Genre
# 540                                             Wonder  ...      Fiction
# 541                                             Wonder  ...      Fiction
# 542                                             Wonder  ...      Fiction
# 543                                             Wonder  ...      Fiction
# 544                                             Wonder  ...      Fiction
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  ...      Fiction
# 546  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 547  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 548  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 549  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
#
# [10 rows x 7 columns]

# %% [markdown]
# ** Descripción básica de columnas: **
#
# Aqui podemos observar el nombre de nuestras columnas

# %%
bdsellers.columns
# Out:
# Index(['Name', 'Author', 'Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %% [markdown]
# Aqui podemos observar con la función dtype el tipo de dato que tenemos.

# %%
bdsellers.dtypes
# Out:
# Name        object
# Author      object
# Rating     float64
# Reviews      int64
# Price        int64
# Year         int64
# Genre       object
# dtype: object

# %% [markdown]
# Aqui podemos observar los valores nulos de cada columna.

# %%
bdsellers.isnull().sum()
# Out:
# Name       0
# Author     0
# Rating     0
# Reviews    0
# Price      0
# Year       0
# Genre      0
# dtype: int64

# %% [markdown]
# **Valores diferentes a cero**
#
# Dado a que buscamos unos resultados mas precisos procederemos a hacer una limpieza identificando los valores con cero para ser posteriormente eliminados

# %% [markdown]
# Analizando todas las variables, concluimos que era necesario el precio del libro debido a que los datos se recabaron por parte de una plataforma de compra online, asi mismo, consideramos que los clientes ademas de las reseñas, se guían por el precio por lo que tener un valor de 0 en precio no tiene razon de ser. Dado esto, eliminaremos las filas que contengan 0.

# %%
cero= bdsellers[bdsellers.Price>0]
cero
# Out:
#                                                   Name  ...        Genre
# 0                        10-Day Green Smoothie Cleanse  ...  Non Fiction
# 1                                    11/22/63: A Novel  ...      Fiction
# 2              12 Rules for Life: An Antidote to Chaos  ...  Non Fiction
# 3                               1984 (Signet Classics)  ...      Fiction
# 4    5,000 Awesome Facts (About Everything!) (Natio...  ...  Non Fiction
# ..                                                 ...  ...          ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  ...      Fiction
# 546  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 547  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 548  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 549  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
#
# [538 rows x 7 columns]

# %% [markdown]
# Posterior a eliminar los datos nulos, guardaremos la base de datos con las modificaciones para continuar con la limpieza

# %%
cero.to_csv('NoCeroPrice.csv')
SINCero=pd.read_csv("NoCeroPrice.csv",index_col=[0])

# %% [markdown]
# Asi mismo, consideramos que los años en los que se comenzaron a vender los libros no nos aprtan informacion útil además de complicar el manejo de datos puesto que hay registros de un mismo libro vendido en difentes años, es por ello que procederemos a eliminar la columna "Price"

# %%
Year=SINCero.drop(['Year'], axis=1)
Year
# Out:
#                                                   Name  ...        Genre
# 0                        10-Day Green Smoothie Cleanse  ...  Non Fiction
# 1                                    11/22/63: A Novel  ...      Fiction
# 2              12 Rules for Life: An Antidote to Chaos  ...  Non Fiction
# 3                               1984 (Signet Classics)  ...      Fiction
# 4    5,000 Awesome Facts (About Everything!) (Natio...  ...  Non Fiction
# ..                                                 ...  ...          ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  ...      Fiction
# 546  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 547  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 548  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 549  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
#
# [538 rows x 6 columns]

# %% [markdown]
# Posteriorimente de eliminar las columnas necesarias, procederemos a crear una nueva base de datos sin los datos no deseados

# %%
Year.to_csv('NoYear.csv')
SINYear=pd.read_csv("NoYear.csv",index_col=[0])

# %% [markdown]
# Volveremos a corroborar que ya no se cuentran con datos nulos

# %%
print("Ceros en author  = ", np.count_nonzero(SINYear.Author== 0))
print("Ceros en name    = ",np.count_nonzero(SINYear.Name== 0))
print("Ceros en rating  = ", np.count_nonzero(SINYear.Rating == 0))
print("Ceros en reviews = ",np.count_nonzero(SINYear.Reviews== 0))
print("Ceros en price   = ",np.count_nonzero(SINYear.Price== 0))
print("Ceros en genre   = ",np.count_nonzero(SINYear.Genre== 0))
# Out:
# Ceros en author  =  0
# Ceros en name    =  0
# Ceros en rating  =  0
# Ceros en reviews =  0
# Ceros en price   =  0
# Ceros en genre   =  0

# %% [markdown]
# **Eliminar columnas no deseadas**
#
# Dado a que todas las columnas son escenciales para la informacion del top seller, no se eleminará ninguna

# %% [markdown]
# #**Estadística básica**
#
# Durante este apartado trabajaremos con nuestra base de datos llamada "SINCero"

# %% [markdown]
# Para comenzar las estadísticas, tomaremos en cuenta todos aquellos dato mayores a 4.9 debido a que la calificacion máxima es de 5, por lo que buscamos saber cuales son los autores y libros mas cotizados

# %%
Mayor=SINYear[SINYear.Rating >= 4.9]
Mayor
# Out:
#                                                   Name  ...        Genre
# 40            Brown Bear, Brown Bear, What Do You See?  ...      Fiction
# 41            Brown Bear, Brown Bear, What Do You See?  ...      Fiction
# 81   Dog Man and Cat Kid: From the Creator of Capta...  ...      Fiction
# 82   Dog Man: A Tale of Two Kitties: From the Creat...  ...      Fiction
# 83   Dog Man: Brawl of the Wild: From the Creator o...  ...      Fiction
# 84   Dog Man: Brawl of the Wild: From the Creator o...  ...      Fiction
# 85   Dog Man: Fetch-22: From the Creator of Captain...  ...      Fiction
# 86   Dog Man: For Whom the Ball Rolls: From the Cre...  ...      Fiction
# 87   Dog Man: Lord of the Fleas: From the Creator o...  ...      Fiction
# 146  Goodnight, Goodnight Construction Site (Hardco...  ...      Fiction
# 147  Goodnight, Goodnight Construction Site (Hardco...  ...      Fiction
# 151                           Hamilton: The Revolution  ...  Non Fiction
# 153  Harry Potter and the Chamber of Secrets: The I...  ...      Fiction
# 155  Harry Potter and the Goblet of Fire: The Illus...  ...      Fiction
# 156  Harry Potter and the Prisoner of Azkaban: The ...  ...      Fiction
# 157  Harry Potter and the Sorcerer's Stone: The Ill...  ...      Fiction
# 174                       Humans of New York : Stories  ...  Non Fiction
# 187  Jesus Calling: Enjoying Peace in His Presence ...  ...  Non Fiction
# 188  Jesus Calling: Enjoying Peace in His Presence ...  ...  Non Fiction
# 189  Jesus Calling: Enjoying Peace in His Presence ...  ...  Non Fiction
# 190  Jesus Calling: Enjoying Peace in His Presence ...  ...  Non Fiction
# 191  Jesus Calling: Enjoying Peace in His Presence ...  ...  Non Fiction
# 192  Jesus Calling: Enjoying Peace in His Presence ...  ...  Non Fiction
# 207  Last Week Tonight with John Oliver Presents A ...  ...      Fiction
# 244                        Obama: An Intimate Portrait  ...  Non Fiction
# 245                          Oh, the Places You'll Go!  ...      Fiction
# 246                          Oh, the Places You'll Go!  ...      Fiction
# 247                          Oh, the Places You'll Go!  ...      Fiction
# 248                          Oh, the Places You'll Go!  ...      Fiction
# 249                          Oh, the Places You'll Go!  ...      Fiction
# 250                          Oh, the Places You'll Go!  ...      Fiction
# 251                          Oh, the Places You'll Go!  ...      Fiction
# 252                          Oh, the Places You'll Go!  ...      Fiction
# 288  Rush Revere and the Brave Pilgrims: Time-Trave...  ...      Fiction
# 289  Rush Revere and the First Patriots: Time-Trave...  ...      Fiction
# 303             Strange Planet (Strange Planet Series)  ...      Fiction
# 420               The Legend of Zelda: Hyrule Historia  ...      Fiction
# 431                                 The Magnolia Story  ...  Non Fiction
# 476                        The Very Hungry Caterpillar  ...      Fiction
# 477                        The Very Hungry Caterpillar  ...      Fiction
# 478                        The Very Hungry Caterpillar  ...      Fiction
# 479                        The Very Hungry Caterpillar  ...      Fiction
# 480                        The Very Hungry Caterpillar  ...      Fiction
# 481                        The Very Hungry Caterpillar  ...      Fiction
# 482                        The Very Hungry Caterpillar  ...      Fiction
# 486                   The Wonderful Things You Will Be  ...      Fiction
# 487                   The Wonderful Things You Will Be  ...      Fiction
# 488                   The Wonderful Things You Will Be  ...      Fiction
# 489                   The Wonderful Things You Will Be  ...      Fiction
# 521                             Unfreedom of the Press  ...  Non Fiction
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  ...      Fiction
#
# [51 rows x 6 columns]

# %%
Mayor.to_csv('Mayor.csv')
UPP=pd.read_csv("Mayor.csv",index_col=[0])

# %% [markdown]
# Como podemos apreciar, los datos aparecen repetidos debido a que exiten varios vendedores que ofrecen el mismo libro y cumplen con la condicion de tener una calificacion mayor a 4.9  por lo que para facilitar el análisis procederemos a agruparlos.

# %%
df=pd.DataFrame(UPP)
unico=df.drop_duplicates(['Name'])
unico
# Out:
#                                                   Name  ...        Genre
# 40            Brown Bear, Brown Bear, What Do You See?  ...      Fiction
# 81   Dog Man and Cat Kid: From the Creator of Capta...  ...      Fiction
# 82   Dog Man: A Tale of Two Kitties: From the Creat...  ...      Fiction
# 83   Dog Man: Brawl of the Wild: From the Creator o...  ...      Fiction
# 85   Dog Man: Fetch-22: From the Creator of Captain...  ...      Fiction
# 86   Dog Man: For Whom the Ball Rolls: From the Cre...  ...      Fiction
# 87   Dog Man: Lord of the Fleas: From the Creator o...  ...      Fiction
# 146  Goodnight, Goodnight Construction Site (Hardco...  ...      Fiction
# 151                           Hamilton: The Revolution  ...  Non Fiction
# 153  Harry Potter and the Chamber of Secrets: The I...  ...      Fiction
# 155  Harry Potter and the Goblet of Fire: The Illus...  ...      Fiction
# 156  Harry Potter and the Prisoner of Azkaban: The ...  ...      Fiction
# 157  Harry Potter and the Sorcerer's Stone: The Ill...  ...      Fiction
# 174                       Humans of New York : Stories  ...  Non Fiction
# 187  Jesus Calling: Enjoying Peace in His Presence ...  ...  Non Fiction
# 207  Last Week Tonight with John Oliver Presents A ...  ...      Fiction
# 244                        Obama: An Intimate Portrait  ...  Non Fiction
# 245                          Oh, the Places You'll Go!  ...      Fiction
# 288  Rush Revere and the Brave Pilgrims: Time-Trave...  ...      Fiction
# 289  Rush Revere and the First Patriots: Time-Trave...  ...      Fiction
# 303             Strange Planet (Strange Planet Series)  ...      Fiction
# 420               The Legend of Zelda: Hyrule Historia  ...      Fiction
# 431                                 The Magnolia Story  ...  Non Fiction
# 476                        The Very Hungry Caterpillar  ...      Fiction
# 486                   The Wonderful Things You Will Be  ...      Fiction
# 521                             Unfreedom of the Press  ...  Non Fiction
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  ...      Fiction
#
# [27 rows x 6 columns]

# %%
len(unico)
# Out:
# 27

# %% [markdown]
# Posteriorimente a eliminar los datos repetidos, volveremos a guardar una base de datos nueva con las modificas recientes hechas

# %%
unico.to_csv('SINRep.csv')
SINRep=pd.read_csv("SINRep.csv",index_col=[0])

# %% [markdown]
# ### **PRICE**

# %% [markdown]
# A continuación calcularemos cual es el  promedio , maximo , varianz  y el rango del precio de la base de datos nueva

# %%
SINRep['Price'] .describe()
# Out:
# count    27.000000
# mean     13.444444
# std      10.966148
# min       4.000000
# 25%       6.500000
# 50%       8.000000
# 75%      17.500000
# max      54.000000
# Name: Price, dtype: float64

# %%
Rangop=SINRep['Price'].max()-SINRep['Price'].min()
Rangop
# Out:
# 50

# %%
SINRep ['Price'] .var()
# Out:
# 120.25641025641029

# %% [markdown]
# Media
#
# El precio de los libros  es de 13.44.
#
# Mediana
#
# El 50% de los libros vendidos tiene un precio menor o igual a 8.
#
# Medidas de dispersión
#
# Varianza
#
# La varianza del precio de los libros vendidos con respecto a la media es de 120.25.
#
# Desviación estándar
#
# La desviación del precio de los libros  con respecto a la media es de 10.96.

# %% [markdown]
# ### **REVIEWS**

# %% [markdown]
# A continuación calcularemos cual es el  promedio ,el mximo , la varianza y  el rango de los reviews de la base de datos nueva

# %%
SINRep [ 'Reviews'] .describe()
# Out:
# count       27.000000
# mean      9213.518519
# std       5458.844597
# min       2812.000000
# 25%       5433.000000
# 50%       7758.000000
# 75%      10966.500000
# max      21834.000000
# Name: Reviews, dtype: float64

# %%
Rangor=SINRep['Reviews'].max()-SINRep['Reviews'].min()
Rangor
# Out:
# 19022

# %%
SINRep ['Reviews'].var()
# Out:
# 29798984.336182334

# %% [markdown]
# Media
#
# El promedio de reviews de los libros  es de 9213.51.
#
# Mediana
#
# El 50% de los libros vendios tienen 77758 reviews.
#
# Medidas de dispersión
#
# Varianza
#
# La varianza del los reviews de los libros vendidos con respecto a la media es de 29798984.336182334
#
# Desviación estándar
#
# La desviación delos reviews de los libros  con respecto a la media es de 5458.844597.

# %% [markdown]
# **Correlación**

# %%
SINRep.corr()
# Out:
#                Rating       Reviews         Price
# Rating   1.000000e+00 -5.030613e-17 -9.781997e-17
# Reviews -5.030613e-17  1.000000e+00 -1.880664e-01
# Price   -9.781997e-17 -1.880664e-01  1.000000e+00

# %% [markdown]
# ### **Gráficas**

# %% [markdown]
#  **Graficas de datos univariantes**

# %%
SINRep['Genre'].value_counts().sort_index().plot.bar()

# %% [markdown]
# Graficando la variable Genre, cuyos posibles resultados son Fiction y No fiction , concluimos que hay mas libros de ficcion.

# %%
SINRep['Price'].value_counts().plot.bar()

# %% [markdown]
# Graficando la variable Genre, cuyos posibles resultados son Fiction y No fiction , concluimos que hay mas libros de ficcion.

# %% [markdown]
# **Gráfica de lineas**

# %%
SINRep['Price'].value_counts().sort_index().plot.line()

# %% [markdown]
# Graficando la variable Price, observamos que el precio drece drásticamente a partir del  6.

# %% [markdown]
# **Histograma**

# %%
SINRep.hist(figsize=(20, 16),color='lightblue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe02c1f8290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe02c708ed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe02bfa3510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe02bf58b90>]],
#       dtype=object)

# %% [markdown]
# **Hexplot**

# %%
SINRep[SINRep['Price'] < 100].plot.hexbin(x='Price', y='Rating', gridsize=15)

# %% [markdown]
# Graficando la variable Price y Rating , podemos darnos cuenta que la existe una concentración en el número 4.9.

# %%
SINRep[SINRep['Price'] < 100].plot.hexbin(x='Price', y='Reviews', gridsize=15)

# %% [markdown]
# Graficando la variable Price y Reseñas , podemos darnos cuenta que la existe una concentración en el número 5000.

# %% [markdown]
# **Kernel Density Estimate "KDE"**

# %%
import seaborn as sns

# %%
sns.kdeplot(SINRep['Price'])

# %% [markdown]
# La gráfica de Kernel density estimate muestra una curva de densidad de probabilidad de la variable del Precio. Además, que uno de nuestros objetivos, es visualizar la distribución de los datos, por lo que es de gran utilidad la gráfica KDE.

# %%
sns.kdeplot(SINRep['Reviews'])

# %% [markdown]
# La gráfica de Kernel density estimate muestra una curva de densidad de probabilidad de la variable de las reseñas. Además, que uno de nuestros objetivos, es visualizar la distribución de los datos, por lo que es de gran utilidad la gráfica KDE.

# %%
sns.kdeplot(data=SINRep, x="Price", y="Reviews")

# %% [markdown]
# Graficando la variable Precio y Reseaña , podemos darnos cuenta que se concentra en x=10 y y=5000

# %% [markdown]
# **Jointplot**

# %%
sns.jointplot(x='Price', y='Reviews', data=SINRep, kind='hex', 
              gridsize=20, color='pink')

# %% [markdown]
# Podemos observar la concentración de los datos de la variable Precio y Reseañas.

# %% [markdown]
# **Pairplot**

# %%
import pandas as pd
import pandas_profiling

# %%
sns.pairplot(data=SINRep[['Price' ,'Rating','Reviews']], height=3)

# %% [markdown]
# **Mapa de calor**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.heatmap(SINRep.corr(),annot=True)
plt.title('Mapa de correlación')
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# ## **Conclusión**

# %% [markdown]
# En conclusion podemos decir que el tipo de genero influye en el preso y la cantidad de reseñas de los libros.
